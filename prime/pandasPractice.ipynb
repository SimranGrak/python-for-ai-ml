# %% [markdown]
# # Pandas practice questions

# %% [markdown]
# # LEVEL-1

# %%
import pandas as pd

# %% [markdown]
# Display the first 5 rows of df.
# Display the last 3 rows of df.
# Find the number of rows and columns.
# Display all column names.
# Display the data types of all columns.
# Select only the Name column.
# Select Name and Marks columns.
# Select the row at index 2.
# Select rows from index 1 to 4.
# Find the average of the Marks column.

# %%
data = {
    "Name": ["Aman", "Priya", "Rahul", "Simran", "Neha", "Karan"],
    "Age": [21, 23, 22, 24, 21, 25],
    "City": ["Delhi", "Mumbai", "Delhi", "Noida", "Mumbai", "Noida"],
    "Marks": [85, 92, 78, 95, 88, 72],
    "Salary": [30000, 45000, 35000, 50000, 40000, 28000]
}

df = pd.DataFrame(data)
df.head()
df.tail(3)
print(df.shape)
print(df.columns)
print(df.info)
# Out:
# (6, 5)
# Index(['Name', 'Age', 'City', 'Marks', 'Salary'], dtype='object')
# <bound method DataFrame.info of      Name  Age    City  Marks  Salary
# 0    Aman   21   Delhi     85   30000
# 1   Priya   23  Mumbai     92   45000
# 2   Rahul   22   Delhi     78   35000
# 3  Simran   24   Noida     95   50000
# 4    Neha   21  Mumbai     88   40000
# 5   Karan   25   Noida     72   28000>

# %%
df
# Out:
#      Name  Age    City  Marks  Salary
# 0    Aman   21   Delhi     85   30000
# 1   Priya   23  Mumbai     92   45000
# 2   Rahul   22   Delhi     78   35000
# 3  Simran   24   Noida     95   50000
# 4    Neha   21  Mumbai     88   40000
# 5   Karan   25   Noida     72   28000
